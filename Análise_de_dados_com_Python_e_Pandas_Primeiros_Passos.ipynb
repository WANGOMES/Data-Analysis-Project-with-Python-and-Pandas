# %% [markdown]
# <a href="https://colab.research.google.com/github/WANGOMES/Data-Analysis-Project-with-Python-and-Pandas/blob/main/An%C3%A1lise_de_dados_com_Python_e_Pandas_Primeiros_Passos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Primeiros Passos: Análise de dados com Python e Pandas**
# Wanderson Gomes

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/01 - Cursos Livres/DIO/Geração Tech Unimed BH - Ciência de Dados/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Gapminder.csv', sep=";" )

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df = df.rename(columns={"country": "País", "continent": "Continente", "year": "Ano", "lifeExp": "Expectativa Vida", "pop": "População", "gdpPercap": "PIB"})

# %%
# total de linhas e colunas
df.shape
# Out:
# (3312, 6)

# %%
# retornar colunas
df.columns
# Out:
# Index(['País', 'Continente', 'Ano', 'Expectativa Vida', 'População', 'PIB'], dtype='object')

# %%
# tipo de dados
df.dtypes
# Out:
# País                 object
# Continente           object
# Ano                   int64
# Expectativa Vida    float64
# População             int64
# PIB                 float64
# dtype: object

# %%
df.head(10)
# Out:
#           País Continente   Ano  Expectativa Vida  População         PIB
# 0  Afghanistan       Asia  1952            28.801    8425333  779.445314
# 1  Afghanistan       Asia  1957            30.332    9240934  820.853030
# 2  Afghanistan       Asia  1962            31.997   10267083  853.100710
# 3  Afghanistan       Asia  1967            34.020   11537966  836.197138
# 4  Afghanistan       Asia  1972            36.088   13079460  739.981106
# 5  Afghanistan       Asia  1977            38.438   14880372  786.113360
# 6  Afghanistan       Asia  1982            39.854   12881816  978.011439
# 7  Afghanistan       Asia  1987            40.822   13867957  852.395945
# 8  Afghanistan       Asia  1992            41.674   16317921  649.341395
# 9  Afghanistan       Asia  1997            41.763   22227415  635.341351

# %%
# ultimas linhas dos dados
df.tail(8)
# Out:
#           País Continente   Ano  Expectativa Vida  População         PIB
# 3304  Zimbabwe     Africa  1972            55.635    5861135  799.362176
# 3305  Zimbabwe     Africa  1977            57.674    6642107  685.587682
# 3306  Zimbabwe     Africa  1982            60.363    7636524  788.855041
# 3307  Zimbabwe     Africa  1987            62.351    9216418  706.157306
# 3308  Zimbabwe     Africa  1992            60.377   10704340  693.420786
# 3309  Zimbabwe     Africa  1997            46.809   11404948  792.449960
# 3310  Zimbabwe     Africa  2002            39.989   11926563  672.038623
# 3311  Zimbabwe     Africa  2007            43.487   12311143  469.709298

# %%
# Describe retorna informações estatísticas do dataset
df.describe()
# Out:
#                Ano  Expectativa Vida     População            PIB
# count  3312.000000       3312.000000  3.312000e+03    3312.000000
# mean   1980.301630         65.246871  3.161489e+07   11317.115805
# std      16.927294         11.768412  1.041193e+08   11369.142739
# min    1950.000000         23.599000  5.941200e+04     241.165876
# 25%    1967.000000         58.337500  2.678572e+06    2514.625266
# 50%    1982.000000         69.610000  7.557218e+06    7838.505123
# 75%    1996.000000         73.657750  1.958522e+07   17357.879170
# max    2007.000000         82.670000  1.318683e+09  113523.132900

# %%
df["Continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
Africa = df.loc[df["Continente"] == "Africa"]
Africa.head()
# Out:
#        País Continente   Ano  Expectativa Vida  População          PIB
# 24  Algeria     Africa  1952            43.077    9279525  2449.008185
# 25  Algeria     Africa  1957            45.685   10270856  3013.976023
# 26  Algeria     Africa  1962            48.303   11000948  2550.816880
# 27  Algeria     Africa  1967            51.407   12760499  3246.991771
# 28  Algeria     Africa  1972            54.518   14760787  4182.663766

# %%
Africa["Continente"].unique()
# Out:
# array(['Africa'], dtype=object)

# %%
df.groupby("Continente")["País"].nunique()
# Out:
# Continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: País, dtype: int64

# %%
# qual a expectativa de vida média por ano
df.groupby("Ano")["Expectativa Vida"].mean()
# Out:
# Ano
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283438
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...
